# %% [markdown]
# # LCLDD Project - Run In Colab
# Make sure to set the **Runtime Type** to **GPU** in the menu above (T4 GPU is fine).

# %%
# !git clone https://github.com/KARTIKPANSURIYA/lcldd.git
# %cd lcldd
# !pip install transformers wandb torch

# %%
# !python precompute_teacher.py

# %%
# !python train.py

# %%
# !python evaluate.py
